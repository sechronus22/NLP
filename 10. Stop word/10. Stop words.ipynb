# %% [markdown]
# ## Stop words
# - content is in the folder of Text representation

# %%
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS

print(len(STOP_WORDS))
print(STOP_WORDS)
# Out:
# 326
# {'after', 're', 'herself', 'what', 'could', 'who', 'against', 'did', 'side', "'d", 'during', 'ever', '’d', 'has', 'whereas', 'alone', 'although', 'make', 'unless', 'can', 'will', 'whereupon', 'perhaps', 'top', 'have', 'me', 'last', 'less', 'though', 'former', 'really', 'eight', 'go', 'thereupon', 'why', 'not', 'often', 'neither', '‘ll', 'mostly', 'whoever', 'wherein', 'up', 'nobody', 'herein', 'and', 'anything', 'five', 'twenty', "'s", 'mine', 'say', 'them', 'bottom', 'otherwise', '’re', 'few', 'most', 'also', 'keep', 'beforehand', 'in', 'down', 'than', 'along', 'when', 'see', 'whenever', 'then', 'became', 'but', 'so', "n't", 'which', 'amount', 'between', 'cannot', 'moreover', 'had', 'front', 'until', 'however', 'seems', 'amongst', 'full', 'two', 'done', 'these', 'besides', '‘s', '’m', 'been', 'whatever', 'an', 'whither', 'always', 'noone', 'there', 'meanwhile', 'becoming', 'beyond', 'we', 'or', 'i', 'anyone', 'no', 'about', 'latter', 'do', 'thereby', 'out', "'re", 'since', 'under', 'three', 'whether', 'get', 'your', "'m", 'both', 'nowhere', 'formerly', 'via', 'they', 'therein', 'please', 'with', 'forty', 'as', 'at', 'hers', 'yet', 'hence', 'that', "'ve", 'nine', 'other', 'into', 'using', 'ourselves', 'never', 'was', 'thence', 'some', 'same', 'thru', 'its', 'yours', 'four', 'by', 'because', 'someone', 'sixty', 'part', 'across', 'put', 'any', 'anyway', 'she', 'around', 'myself', 'one', 'while', 'seem', 'everywhere', '’ll', 'towards', 'several', 'hereby', 'serious', 'each', 'regarding', 'whereafter', 'various', 'must', 'thereafter', '‘ve', 'yourselves', 'back', 'below', 'nor', 'made', 'ten', 'whom', 'being', 'everyone', 'should', 'sometimes', 'yourself', 'for', 'take', 'here', 'afterwards', 'n‘t', 'wherever', 'behind', 'how', 'empty', 'n’t', 'used', 'were', 'whose', 'hereupon', 'us', '’ve', 'the', 'somehow', 'my', 'indeed', 'whence', 'still', 'name', 'be', 'latterly', 'throughout', 'fifty', 'very', 'this', 'are', 'a', 'seemed', 'over', 'onto', "'ll", 'more', 'almost', 'ca', '‘d', 'on', 'least', 'to', 'once', 'eleven', 'something', 'his', 'beside', 'many', 'too', 'together', 'move', 'just', 'is', 'it', 'nevertheless', 'give', 'again', 'off', 'hereafter', 'due', 'hundred', 'else', 'another', 'next', 'therefore', 'first', 'others', 'much', 'you', 'either', 'well', 'seeming', 'anywhere', 'already', 'above', 'becomes', 'sometime', 'those', 'now', 'only', 'own', 'show', 'their', 'may', 'such', '‘m', 'none', 'somewhere', 'third', 'might', 'doing', 'except', 'itself', 'call', 'if', 'from', 'within', 'upon', 'every', 'himself', 'whole', 'themselves', 'become', 'everything', '’s', 'him', 'does', 'would', 'through', 'twelve', 'enough', 'thus', 'toward', 'without', 'elsewhere', 'fifteen', 'namely', 'per', 'am', 'where', 'ours', 'further', 'even', 'anyhow', 'whereby', '‘re', 'our', 'before', 'among', 'rather', 'her', 'six', 'nothing', 'quite', 'of', 'all', 'he'}

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("We just opened our wings, the flying part is coming soon")
for token in doc:
  if token.is_stop:
    print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
print(len(nlp.Defaults.stop_words))
print(nlp.Defaults.stop_words)
# Out:
# 326
# {'after', 're', 'herself', 'what', 'could', 'who', 'against', 'did', 'side', "'d", 'during', 'ever', '’d', 'has', 'whereas', 'alone', 'although', 'make', 'unless', 'can', 'will', 'whereupon', 'perhaps', 'top', 'have', 'me', 'last', 'less', 'though', 'former', 'really', 'eight', 'go', 'thereupon', 'why', 'not', 'often', 'neither', '‘ll', 'mostly', 'whoever', 'wherein', 'up', 'nobody', 'herein', 'and', 'anything', 'five', 'twenty', "'s", 'mine', 'say', 'them', 'bottom', 'otherwise', '’re', 'few', 'most', 'also', 'keep', 'beforehand', 'in', 'down', 'than', 'along', 'when', 'see', 'whenever', 'then', 'became', 'but', 'so', "n't", 'which', 'amount', 'between', 'cannot', 'moreover', 'had', 'front', 'until', 'however', 'seems', 'amongst', 'full', 'two', 'done', 'these', 'besides', '‘s', '’m', 'been', 'whatever', 'an', 'whither', 'always', 'noone', 'there', 'meanwhile', 'becoming', 'beyond', 'we', 'or', 'i', 'anyone', 'no', 'about', 'latter', 'do', 'thereby', 'out', "'re", 'since', 'under', 'three', 'whether', 'get', 'your', "'m", 'both', 'nowhere', 'formerly', 'via', 'they', 'therein', 'please', 'with', 'forty', 'as', 'at', 'hers', 'yet', 'hence', 'that', "'ve", 'nine', 'other', 'into', 'using', 'ourselves', 'never', 'was', 'thence', 'some', 'same', 'thru', 'its', 'yours', 'four', 'by', 'because', 'someone', 'sixty', 'part', 'across', 'put', 'any', 'anyway', 'she', 'around', 'myself', 'one', 'while', 'seem', 'everywhere', '’ll', 'towards', 'several', 'hereby', 'serious', 'each', 'regarding', 'whereafter', 'various', 'must', 'thereafter', '‘ve', 'yourselves', 'back', 'below', 'nor', 'made', 'ten', 'whom', 'being', 'everyone', 'should', 'sometimes', 'yourself', 'for', 'take', 'here', 'afterwards', 'n‘t', 'wherever', 'behind', 'how', 'empty', 'n’t', 'used', 'were', 'whose', 'hereupon', 'us', '’ve', 'the', 'somehow', 'my', 'indeed', 'whence', 'still', 'name', 'be', 'latterly', 'throughout', 'fifty', 'very', 'this', 'are', 'a', 'seemed', 'over', 'onto', "'ll", 'more', 'almost', 'ca', '‘d', 'on', 'least', 'to', 'once', 'eleven', 'something', 'his', 'beside', 'many', 'too', 'together', 'move', 'just', 'is', 'it', 'nevertheless', 'give', 'again', 'off', 'hereafter', 'due', 'hundred', 'else', 'another', 'next', 'therefore', 'first', 'others', 'much', 'you', 'either', 'well', 'seeming', 'anywhere', 'already', 'above', 'becomes', 'sometime', 'those', 'now', 'only', 'own', 'show', 'their', 'may', 'such', '‘m', 'none', 'somewhere', 'third', 'might', 'doing', 'except', 'itself', 'call', 'if', 'from', 'within', 'upon', 'every', 'himself', 'whole', 'themselves', 'become', 'everything', '’s', 'him', 'does', 'would', 'through', 'twelve', 'enough', 'thus', 'toward', 'without', 'elsewhere', 'fifteen', 'namely', 'per', 'am', 'where', 'ours', 'further', 'even', 'anyhow', 'whereby', '‘re', 'our', 'before', 'among', 'rather', 'her', 'six', 'nothing', 'quite', 'of', 'all', 'he'}

# %%
def preprocess(text):
  doc = nlp(text)

  no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
  return no_stop_words

preprocess("We just opened our wings, the flying part is coming soon")
# Out:
# ['opened', 'wings', 'flying', 'coming', 'soon']

# %% [markdown]
# **Remove stop words from pandas dataframe text column**
#
# Dataset is downloaded from: https://www.kaggle.com/datasets/jbencina/department-of-justice-20092018-press-releases It contains press releases of different court cases from depart of justice (DOJ). The releases contain information such as outcomes of criminal cases, notable actions taken against felons, or other updates about the current administration.

# %%
cd /content/drive/MyDrive/Study/NLP/codebasics/10. Stop word
# Out:
# /content/drive/MyDrive/Study/NLP/codebasics/10. Stop word

# %%
import pandas as pd

df = pd.read_json("doj_press.json", lines = True)
df.shape
# Out:
# (13087, 6)

# %%
df.head()
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# 4  2018-07-09T00:00:00-04:00  [Environment]
#
#                                      components
# 0            [National Security Division (NSD)]
# 1  [Environment and Natural Resources Division]
# 2  [Environment and Natural Resources Division]
# 3  [Environment and Natural Resources Division]
# 4  [Environment and Natural Resources Division]

# %% [markdown]
# Filter out those rows that do not have any topics associated with the case

# %%
df = df[df["topics"].str.len() != 0]
df.head()
# Out:
#          id                                              title  \
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7   14-1412  14 Indicted in Connection with New England Com...
# 19  17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22  15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23  17-1404  21st Century Oncology to Pay $26 Million to Se...
#
#                                              contents  \
# 4   The U.S. Department of Justice, the U.S. Envir...
# 7   A 131-count criminal indictment was unsealed t...
# 19  The United States Attorney’s Office for the Mi...
# 22  21st Century Oncology LLC, has agreed to pay $...
# 23  21st Century Oncology Inc. and certain of its ...
#
#                          date                                 topics  \
# 4   2018-07-09T00:00:00-04:00                          [Environment]
# 7   2014-12-17T00:00:00-05:00                  [Consumer Protection]
# 19  2017-12-14T00:00:00-05:00                          [Environment]
# 22  2015-12-18T00:00:00-05:00  [False Claims Act, Health Care Fraud]
# 23  2017-12-12T00:00:00-05:00  [Health Care Fraud, False Claims Act]
#
#                                            components
# 4        [Environment and Natural Resources Division]
# 7                                    [Civil Division]
# 19  [Environment and Natural Resources Division, U...
# 22                                   [Civil Division]
# 23           [Civil Division, USAO - Florida, Middle]

# %%
df.shape
# Out:
# (4688, 6)

# %%
df = df.head(100)

# %%
def preprocess(text):
  doc = nlp(text)

  no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
  return " ".join(no_stop_words)

# %%
df["contents_new"] = df.contents.apply(preprocess)

# %%
df.head()
# Out:
#          id                                              title  \
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7   14-1412  14 Indicted in Connection with New England Com...
# 19  17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22  15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23  17-1404  21st Century Oncology to Pay $26 Million to Se...
#
#                                              contents  \
# 4   The U.S. Department of Justice, the U.S. Envir...
# 7   A 131-count criminal indictment was unsealed t...
# 19  The United States Attorney’s Office for the Mi...
# 22  21st Century Oncology LLC, has agreed to pay $...
# 23  21st Century Oncology Inc. and certain of its ...
#
#                          date                                 topics  \
# 4   2018-07-09T00:00:00-04:00                          [Environment]
# 7   2014-12-17T00:00:00-05:00                  [Consumer Protection]
# 19  2017-12-14T00:00:00-05:00                          [Environment]
# 22  2015-12-18T00:00:00-05:00  [False Claims Act, Health Care Fraud]
# 23  2017-12-12T00:00:00-05:00  [Health Care Fraud, False Claims Act]
#
#                                            components  \
# 4        [Environment and Natural Resources Division]
# 7                                    [Civil Division]
# 19  [Environment and Natural Resources Division, U...
# 22                                   [Civil Division]
# 23           [Civil Division, USAO - Florida, Middle]
#
#                                          contents_new
# 4   U.S. Department Justice U.S. Environmental Pro...
# 7   131 count criminal indictment unsealed today B...
# 19  United States Attorney Office Middle District ...
# 22  21st Century Oncology LLC agreed pay $ 19.75 m...
# 23  21st Century Oncology Inc. certain subsidiarie...

# %% [markdown]
# original content vs content after remove stop words

# %%
print('original length:', len(df['contents'].iloc[4]))
print('modify length:', len(df['contents_new'].iloc[4]))
# Out:
# original length: 5504
# modify length: 4217
