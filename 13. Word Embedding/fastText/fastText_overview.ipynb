# %% [markdown]
# ## FastText
# - One of Word Embedding techniques like Word2Vec
# - Instead of using **WORD** as the unit of neural network training like Word2Vec, fastText use CHARACTER n gram instead
# - For example, if the word is capable and we use n=3, we will have cap, apa, pab, aba, abl, ble.
# - This makes fastText handle OOV (out of vocab) better than Word2Vec
# - Better when we want to train custom word embedding.

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# ...
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp311-cp311-linux_x86_64.whl size=4313503 sha256=c42882d843f820323e040a35121336fb60608d65ffbfd64a3aa41d96c990657c
#   Stored in directory: /root/.cache/pip/wheels/65/4f/35/5057db0249224e9ab55a513fa6b79451473ceb7713017823c3
# Successfully built fasttext
# ...

# %%
cd /content/drive/MyDrive/Study/NLP/codebasics/13. Word Embedding/fastText
# Out:
# /content/drive/MyDrive/Study/NLP/codebasics/13. Word Embedding/fastText

# %%
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')
# Out:
# ...
# 'cc.en.300.bin'

# %%
import fasttext

model_en = fasttext.load_model('cc.en.300.bin')

# %%
model_en.get_nearest_neighbors("good")
# Out:
# [(0.7517593502998352, 'bad'),
#  (0.7426098585128784, 'great'),
#  (0.7299689054489136, 'decent'),
#  (0.7123614549636841, 'nice'),
#  (0.6796907186508179, 'Good'),
#  (0.6737031936645508, 'excellent'),
#  (0.669592022895813, 'goood'),
#  (0.6602178812026978, 'ggod'),
#  (0.6479219794273376, 'semi-good'),
#  (0.6417751908302307, 'good.Good')]

# %%
model_en.get_word_vector("good")
# Out:
# array([-0.09213716, -0.0634383 ,  0.00173813,  0.13524324, -0.06561062,
#         0.00619071,  0.12609869, -0.01646539,  0.0174491 , -0.00126792,
#        -0.09709831,  0.02329333,  0.00996784,  0.00463419,  0.01587938,
#         0.00689824,  0.08575399, -0.01988525, -0.0601579 , -0.02327966,
#         0.01183712,  0.08217917,  0.01488847,  0.00902181,  0.00696296,
#        -0.06426616,  0.03345198, -0.02101481,  0.06767873,  0.03022419,
#         0.07203474, -0.05689922, -0.04370377,  0.00642597,  0.0439174 ,
#         0.0604848 , -0.00611545, -0.12256738, -0.03530414, -0.02696739,
#        -0.02058216,  0.00752347, -0.00686451,  0.0362783 , -0.03308735,
#         0.05801626,  0.00832448, -0.06336953, -0.05775082,  0.01089846,
#        -0.0925179 ,  0.01559984, -0.04079024,  0.0066871 , -0.06374165,
#         0.05881973,  0.07209535, -0.05387195, -0.14658651, -0.04046486,
#        -0.02507038, -0.04954465, -0.05224417, -0.06846938,  0.0467079 ,
# ...

# %%
model_en.get_analogies("berlin","gemany","india")
# Out:
# [(0.6480075716972351, 'delhi'),
#  (0.6370160579681396, 'germany'),
#  (0.6110430955886841, 'austria'),
#  (0.6106089353561401, 'singapore'),
#  (0.6102327108383179, 'bangalore'),
#  (0.609043300151825, 'france'),
#  (0.6076514720916748, 'belgium'),
#  (0.6052702069282532, 'australia'),
#  (0.5984387993812561, 'europe'),
#  (0.5968400835990906, 'dubai')]

# %%
model_en.get_analogies("driving","car","phone")
# Out:
# [(0.610385537147522, 'texting'),
#  (0.5203558802604675, 'phone-calling'),
#  (0.5153835415840149, 'cellphone'),
#  (0.5135326981544495, 'cell-phone'),
#  (0.5117910504341125, 'dialing'),
#  (0.5087355971336365, 'texing'),
#  (0.5079342722892761, 'text-messaging'),
#  (0.500900387763977, 'txting'),
#  (0.4960441589355469, 'texting.'),
#  (0.4951859414577484, 'Texting')]

# %%
model_en.get_analogies("driving","car","book")
# Out:
# [(0.5302355885505676, 'reading'),
#  (0.517051637172699, 'book.I'),
#  (0.5137901306152344, 'book--and'),
#  (0.5090512633323669, 'book.That'),
#  (0.5005884766578674, 'book--it'),
#  (0.49395182728767395, 'book--I'),
#  (0.49293914437294006, 're-reading'),
#  (0.49156999588012695, 'book.This'),
#  (0.49107635021209717, 'reading--and'),
#  (0.48960915207862854, 'book--the')]

# %% [markdown]
# ## Custom train word embeddings on indian food receipes 😋
# * Since common pretrained model does not understand or not work well on indian food, so we have to train our own model for indian food.
# * **dataset credits**: https://www.kaggle.com/datasets/sooryaprakash12/cleaned-indian-recipes-dataset

# %%
import pandas as pd

df = pd.read_csv("Cleaned_Indian_Food_Dataset.csv")
df.head()
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  TotalTimeInMins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  1 Onion - sliced,1 teaspoon White Urad Dal (Sp...               50
# 3  1/2 teaspoon Turmeric powder (Haldi),1 tablesp...               45
# 4   oil - as per use, 1 tablespoon coriander seed...               30
#
#                 Cuisine                             TranslatedInstructions  \
# 0                Indian  To begin making the Masala Karela Recipe,de-se...
# ...

# %%
df.shape
# Out:
# (5938, 9)

# %%
df.TranslatedInstructions[0]
# Out:
# 'To begin making the Masala Karela Recipe,de-seed the karela and slice.\nDo not remove the skin as the skin has all the nutrients.\nAdd the karela to the pressure cooker with 3 tablespoon of water, salt and turmeric powder and pressure cook for three whistles.\nRelease the pressure immediately and open the lids.\nKeep aside.Heat oil in a heavy bottomed pan or a kadhai.\nAdd cumin seeds and let it sizzle.Once the cumin seeds have sizzled, add onions and saute them till it turns golden brown in color.Add the karela, red chilli powder, amchur powder, coriander powder and besan.\nStir to combine the masalas into the karela.Drizzle a little extra oil on the top and mix again.\nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well.\nTurn off the heat.Transfer Masala Karela into a serving bowl and serve.Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.\n'

# %%
# remove punctuation, and special character(fullstop)
import re

text = "To begin making the Masala Karela Recipe,de-seed the karela and slice.\nDo not remove the skin as the skin has all the nutrients.\nAdd the karela to the pressure cooker with 3 tablespoon of water, salt and turmeric powder and pressure cook for three whistles.\nRelease the pressure immediately and open the lids.\nKeep aside.Heat oil in a heavy bottomed pan or a kadhai.\nAdd cumin seeds and let it sizzle.Once the cumin seeds have sizzled, add onions and saute them till it turns golden brown in color.Add the karela, red chilli powder, amchur powder, coriander powder and besan.\nStir to combine the masalas into the karela.Drizzle a little extra oil on the top and mix again.\nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well.\nTurn off the heat.Transfer Masala Karela into a serving bowl and serve.Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.\n"
re.sub(r'[^\w\s]', ' ', text, flags = re.MULTILINE)
# Out:
# 'To begin making the Masala Karela Recipe de seed the karela and slice \nDo not remove the skin as the skin has all the nutrients \nAdd the karela to the pressure cooker with 3 tablespoon of water  salt and turmeric powder and pressure cook for three whistles \nRelease the pressure immediately and open the lids \nKeep aside Heat oil in a heavy bottomed pan or a kadhai \nAdd cumin seeds and let it sizzle Once the cumin seeds have sizzled  add onions and saute them till it turns golden brown in color Add the karela  red chilli powder  amchur powder  coriander powder and besan \nStir to combine the masalas into the karela Drizzle a little extra oil on the top and mix again \nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well \nTurn off the heat Transfer Masala Karela into a serving bowl and serve Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family \n'

# %%
# remove \n and multi space after substitute character with space
re.sub(r'[ \n]+', ' ', "powder  coriander powder and besan \nStir to")
# Out:
# 'powder coriander powder and besan Stir to'

# %%
def preprocess(text):
  text = re.sub(r'[^\w\s]', ' ', text, flags = re.MULTILINE)
  text = re.sub(r'[ \n]+', ' ', text)
  return text

preprocess(text)
# Out:
# 'To begin making the Masala Karela Recipe de seed the karela and slice Do not remove the skin as the skin has all the nutrients Add the karela to the pressure cooker with 3 tablespoon of water salt and turmeric powder and pressure cook for three whistles Release the pressure immediately and open the lids Keep aside Heat oil in a heavy bottomed pan or a kadhai Add cumin seeds and let it sizzle Once the cumin seeds have sizzled add onions and saute them till it turns golden brown in color Add the karela red chilli powder amchur powder coriander powder and besan Stir to combine the masalas into the karela Drizzle a little extra oil on the top and mix again Cover the pan and simmer Masala Karela stirring occasionally until everything comes together well Turn off the heat Transfer Masala Karela into a serving bowl and serve Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family '

# %%
df.TranslatedInstructions = df.TranslatedInstructions.map(preprocess)
df.TranslatedInstructions[0]
# Out:
# 'To begin making the Masala Karela Recipe de seed the karela and slice Do not remove the skin as the skin has all the nutrients Add the karela to the pressure cooker with 3 tablespoon of water salt and turmeric powder and pressure cook for three whistles Release the pressure immediately and open the lids Keep aside Heat oil in a heavy bottomed pan or a kadhai Add cumin seeds and let it sizzle Once the cumin seeds have sizzled add onions and saute them till it turns golden brown in color Add the karela red chilli powder amchur powder coriander powder and besan Stir to combine the masalas into the karela Drizzle a little extra oil on the top and mix again Cover the pan and simmer Masala Karela stirring occasionally until everything comes together well Turn off the heat Transfer Masala Karela into a serving bowl and serve Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family '

# %%
df.to_csv("food_receipes.txt", columns=["TranslatedInstructions"], header=None, index=False)

# %%
import fasttext

model = fasttext.train_unsupervised("food_receipes.txt")

# %%
model.get_nearest_neighbors("paneer")
# Out:
# [(0.6743189692497253, 'Paneer'),
#  (0.6569597125053406, 'tikka'),
#  (0.6533766388893127, 'tikkas'),
#  (0.6511157155036926, 'tofu'),
#  (0.6338105797767639, 'satay'),
#  (0.6119581460952759, 'bhurji'),
#  (0.599346935749054, 'cottage'),
#  (0.595426082611084, 'tandoori'),
#  (0.5872913002967834, 'malai'),
#  (0.5871977806091309, 'grilling')]

# %%
model.get_nearest_neighbors("chutney")
# Out:
# [(0.9555993676185608, 'chutneys'),
#  (0.8382540345191956, 'Chutney'),
#  (0.6843678951263428, 'pudina'),
#  (0.681654155254364, 'dhaniya'),
#  (0.6530480980873108, 'Imli'),
#  (0.6389256119728088, 'Tamarind'),
#  (0.6157044768333435, 'Dhaniya'),
#  (0.599093496799469, 'Khajur'),
#  (0.5978357791900635, 'Mavinakayi'),
#  (0.592095673084259, 'pachadi')]

# %%
model.get_nearest_neighbors("halwa")
# Out:
# [(0.7511956691741943, 'Halwa'),
#  (0.7496204972267151, 'khoya'),
#  (0.7322367429733276, 'gajar'),
#  (0.7085256576538086, 'badam'),
#  (0.6977255940437317, 'kheer'),
#  (0.6760193109512329, 'mawa'),
#  (0.6717345714569092, 'burfi'),
#  (0.6603620052337646, 'kesar'),
#  (0.6595414280891418, 'rabri'),
#  (0.6581591963768005, 'porridge')]

# %%
model.get_nearest_neighbors("dosa")
# Out:
# [(0.8138796091079712, 'dosas'),
#  (0.7712641358375549, 'Dosa'),
#  (0.754006028175354, 'uttapam'),
#  (0.6903491616249084, 'Unniyappam'),
#  (0.6889681816101074, 'appam'),
#  (0.6866046190261841, 'Dosai'),
#  (0.6706693768501282, 'Uttapam'),
#  (0.6696944236755371, 'pesarattu'),
#  (0.6654890775680542, 'Uthappam'),
#  (0.6544554233551025, 'Pesarattu')]

# %%
model.get_word_vector("dosa").shape
# Out:
# (100,)
